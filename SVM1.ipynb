# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, classification_report
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions
import numpy as np
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("C:/Users/prash/Downloads/creditset.csv")

# %%
X = data.iloc[:, [2, 4]]
y = data.iloc[:, 5]
X_train = X[:-200]
X_test = X[-200:]
y_train = y[:-200]
y_test = y[-200:]

# %%
SVC?

# %%
svm = SVC(C = 9, kernel = 'rbf', random_state = 100)

# %%
model = svm.fit(X_train, y_train)

# %%
predictions = model.predict(X_test)

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.96999999999999997

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98       172
#           1       0.89      0.89      0.89        28
#
# avg / total       0.97      0.97      0.97       200

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[169,   3],
#        [  3,  25]])

# %%
plot_decision_regions(X=pd.DataFrame.as_matrix(X_train), y=pd.DataFrame.as_matrix(y_train), clf=model, legend=1)

# %%
plot_decision_regions?

# %%
# Update plot object with X/Y axis labels and Figure Title
plt.xlabel(X.columns[0], size=10)
plt.ylabel(X.columns[1], size=10)
plt.ylim(0, 0.25)
plt.title('SVM Decision Region Boundary', size=16)

# %%
plt.show()

# %%
plot_decision_regions?
